SmatrixProd2TF = [0.116, 0.115, 0.122, 0.116, 0.115, 0.122, 0.116, 0.115, 0.122, 0.116, 0.115, 0.122, 0.116, 0.115, 0.122, 0.116, 0.115, 0.122, 0.116, 0.115]
#####
SmatrixProd3O = [578, 543, 541, 578, 543, 541, 578, 543, 541, 578, 543, 541, 578, 543, 541, 578, 543, 541, 578, 543]
SmatrixProd3WS = [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]
SmatrixProd3WE = [6.3, 6.3, 6.2, 6.3, 6.3, 6.2, 6.3, 6.3, 6.2, 6.3, 6.3, 6.2, 6.3, 6.3, 6.2, 6.3, 6.3, 6.2, 6.3, 6.3]
SmatrixProd3WF = [6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3]
SmatrixProd3TS = [0.394, 0.403, 0.431, 0.394, 0.403, 0.431, 0.394, 0.403, 0.431, 0.394, 0.403, 0.431, 0.394, 0.403, 0.431, 0.394, 0.403, 0.431, 0.394, 0.403]
SmatrixProd3TE = [0.438, 0.294, 0.293, 0.438, 0.294, 0.293, 0.438, 0.294, 0.293, 0.438, 0.294, 0.293, 0.438, 0.294, 0.293, 0.438, 0.294, 0.293, 0.438, 0.294]
SmatrixProd3TF = [0.123, 0.118, 0.108, 0.123, 0.118, 0.108, 0.123, 0.118, 0.108, 0.123, 0.118, 0.108, 0.123, 0.118, 0.108, 0.123, 0.118, 0.108, 0.123, 0.118]
#####
SmatrixProd4O = [558, 595, 557, 558, 595, 557, 558, 595, 557, 558, 595, 557, 558, 595, 557, 558, 595, 557, 558, 595]
SmatrixProd4WS = [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]
SmatrixProd4WE = [6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.2, 6.3, 6.3, 6.3, 6.3, 6.3, 6.2, 6.3, 6.1]
SmatrixProd4WF = [6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.2, 6.3, 6.3, 6.3, 6.3, 6.1]
SmatrixProd4TS = [0.422, 1.886, 0.44, 0.422, 1.886, 0.44, 0.422, 1.886, 0.44, 0.422, 1.886, 0.44, 0.422, 1.886, 0.44, 0.422, 1.886, 0.44, 0.422, 1.886]
SmatrixProd4TE = [0.521, 0.364, 0.459, 0.521, 0.364, 0.459, 0.521, 0.364, 0.459, 0.521, 0.364, 0.459, 0.521, 0.364, 0.459, 0.521, 0.364, 0.459, 0.521, 0.364]
SmatrixProd4TF = [0.097, 0.11, 0.12, 0.097, 0.11, 0.12, 0.097, 0.11, 0.12, 0.097, 0.11, 0.12, 0.097, 0.11, 0.12, 0.097, 0.11, 0.12, 0.097, 0.11]

# %%
# Cfloat Native vs Docker vs Singulariy
#####
Ncfloat1OW = np.mean(Ncfloat1O) / np.mean(Ncfloat1W)
Dcfloat1OW = np.mean(Dcfloat1O) / np.mean(Dcfloat1WE)
Scfloat1OW = np.mean(Scfloat1O) / np.mean(Scfloat1WE)
Ncfloat2OW = np.mean(Ncfloat2O) / np.mean(Ncfloat2W)
Dcfloat2OW = np.mean(Dcfloat2O) / np.mean(Dcfloat2WE)
Scfloat2OW = np.mean(Scfloat2O) / np.mean(Scfloat2WE)
Ncfloat3OW = np.mean(Ncfloat3O) / np.mean(Ncfloat3W)
Dcfloat3OW = np.mean(Dcfloat3O) / np.mean(Dcfloat3WE)
Scfloat3OW = np.mean(Scfloat3O) / np.mean(Scfloat3WE)
Ncfloat4OW = np.mean(Ncfloat4O) / np.mean(Ncfloat4W)
Dcfloat4OW = np.mean(Dcfloat4O) / np.mean(Dcfloat4WE)
Scfloat4OW = np.mean(Scfloat4O) / np.mean(Scfloat4WE)

categorias = ["1", "2", "3", "4"]
valores1 = [Ncfloat1OW, Ncfloat2OW, Ncfloat3OW, Ncfloat4OW]
valores2 = [Dcfloat1OW, Dcfloat2OW, Dcfloat3OW, Dcfloat4OW]
valores3 = [Scfloat1OW, Scfloat2OW, Scfloat3OW, Scfloat4OW]
# Posición en el eje x para cada categoría
x = np.arange(len(categorias))
# Ancho de las barras
ancho = 0.3
# Crear el gráfico de barras
plt.figure(figsize=(16,9))
bar1 = plt.bar(x, valores1, ancho, label='Native', color='purple')
bar2 = plt.bar(x + ancho, valores2, ancho, label='Docker', color='red')
bar3 = plt.bar(x + 2*ancho, valores3, ancho, label='Singularity', color='blue')
# Etiquetas en el eje
plt.xticks(x + ancho, categorias, fontsize=20)
plt.yticks( fontsize=20)
# Etiquetas de título y ejes
plt.title('Cfloat', fontsize=40)
plt.xlabel('Cores', fontsize=30)
plt.ylabel('OPS/W', fontsize=30)
# Agregar leyenda
plt.legend(fontsize=20)
# Generar IMG
#plt.savefig('cfloat.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico en la ventana de la aplicación
plt.show()

# %%
# Correlate Native vs Docker vs Singulariy
# Mostrar el gráfico en la ventana de la aplicación
Ncorrelate1OW = np.mean(Ncorrelate1O) / np.mean(Ncorrelate1W)
Dcorrelate1OW = np.mean(Dcorrelate1O) / np.mean(Dcorrelate1WE)
Scorrelate1OW = np.mean(Scorrelate1O) / np.mean(Scorrelate1WE)
Ncorrelate2OW = np.mean(Ncorrelate2O) / np.mean(Ncorrelate2W)
Dcorrelate2OW = np.mean(Dcorrelate2O) / np.mean(Dcorrelate2WE)
Scorrelate2OW = np.mean(Scorrelate2O) / np.mean(Scorrelate2WE)
Ncorrelate3OW = np.mean(Ncorrelate3O) / np.mean(Ncorrelate3W)
Dcorrelate3OW = np.mean(Dcorrelate3O) / np.mean(Dcorrelate3WE)
Scorrelate3OW = np.mean(Scorrelate3O) / np.mean(Scorrelate3WE)
Ncorrelate4OW = np.mean(Ncorrelate4O) / np.mean(Ncorrelate4W)
Dcorrelate4OW = np.mean(Dcorrelate4O) / np.mean(Dcorrelate4WE)
Scorrelate4OW = np.mean(Scorrelate4O) / np.mean(Scorrelate4WE)

categorias = ["1", "2", "3", "4"]
valores1 = [Ncorrelate1OW, Ncorrelate2OW, Ncorrelate3OW, Ncorrelate4OW]
valores2 = [Dcorrelate1OW, Dcorrelate2OW, Dcorrelate3OW, Dcorrelate4OW]
valores3 = [Scorrelate1OW, Scorrelate2OW, Scorrelate3OW, Scorrelate4OW]
# Posición en el eje x para cada categoría
x = np.arange(len(categorias))
# Ancho de las barras
ancho = 0.3
# Crear el gráfico de barras
plt.figure(figsize=(16,9))
bar1 = plt.bar(x, valores1, ancho, label='Native', color='purple')
bar2 = plt.bar(x + ancho, valores2, ancho, label='Docker', color='red')
bar3 = plt.bar(x + 2*ancho, valores3, ancho, label='Singularity', color='blue')
# Etiquetas en el eje x
plt.xticks(x + ancho, categorias, fontsize=20)
plt.yticks( fontsize=20)
# Etiquetas de título y ejes
plt.title('Correlate', fontsize=40)
plt.xlabel('Cores', fontsize=30)
plt.ylabel('OPS/W', fontsize=30)
# Agregar leyenda
plt.legend(fontsize=20)
# Generar IMG
#plt.savefig('correlate.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico en la ventana de la aplicación
plt.show()

# %%
# Prime Native vs Docker vs Singulariy
# Mostrar el gráfico en la ventana de la aplicación
Nprime1OW = np.mean(Nprime1O) / np.mean(Nprime1W)
Dprime1OW = np.mean(Dprime1O) / np.mean(Dprime1WE)
Sprime1OW = np.mean(Sprime1O) / np.mean(Sprime1WE)
Nprime2OW = np.mean(Nprime2O) / np.mean(Nprime2W)
Dprime2OW = np.mean(Dprime2O) / np.mean(Dprime2WE)
Sprime2OW = np.mean(Sprime2O) / np.mean(Sprime2WE)
Nprime3OW = np.mean(Nprime3O) / np.mean(Nprime3W)
Dprime3OW = np.mean(Dprime3O) / np.mean(Dprime3WE)
Sprime3OW = np.mean(Sprime3O) / np.mean(Sprime3WE)
Nprime4OW = np.mean(Nprime4O) / np.mean(Nprime4W)
Dprime4OW = np.mean(Dprime4O) / np.mean(Dprime4WE)
Sprime4OW = np.mean(Sprime4O) / np.mean(Sprime4WE)

categorias = ["1", "2", "3", "4"]
valores1 = [Nprime1OW, Nprime2OW, Nprime3OW, Nprime4OW]
valores2 = [Dprime1OW, Dprime2OW, Dprime3OW, Dprime4OW]
valores3 = [Sprime1OW, Sprime2OW, Sprime3OW, Sprime4OW]
# Posición en el eje x para cada categoría
x = np.arange(len(categorias))
# Ancho de las barras
ancho = 0.3
# Crear el gráfico de barras
plt.figure(figsize=(16,9))
bar1 = plt.bar(x, valores1, ancho, label='Native', color='purple')
bar2 = plt.bar(x + ancho, valores2, ancho, label='Docker', color='red')
bar3 = plt.bar(x + 2*ancho, valores3, ancho, label='Singularity', color='blue')
# Etiquetas en el eje x
plt.xticks(x + ancho, categorias, fontsize=20)
plt.yticks( fontsize=20)
# Etiquetas de título y ejes
plt.title('Prime', fontsize=40)
plt.xlabel('Cores', fontsize=30)
plt.ylabel('OPS/W', fontsize=30)
# Agregar leyenda
plt.legend(fontsize=20)
# Generar IMG
#plt.savefig('prime.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico en la ventana de la aplicación
plt.show()

# %%
# MatrixProd Native vs Docker vs Singulariy
# Mostrar el gráfico en la ventana de la aplicación
NmatrixProd1OW = np.mean(NmatrixProd1O) / np.mean(NmatrixProd1W)
DmatrixProd1OW = np.mean(DmatrixProd1O) / np.mean(DmatrixProd1WE)
SmatrixProd1OW = np.mean(SmatrixProd1O) / np.mean(SmatrixProd1WE)
NmatrixProd2OW = np.mean(NmatrixProd2O) / np.mean(NmatrixProd2W)
DmatrixProd2OW = np.mean(DmatrixProd2O) / np.mean(DmatrixProd2WE)
SmatrixProd2OW = np.mean(SmatrixProd2O) / np.mean(SmatrixProd2WE)
NmatrixProd3OW = np.mean(NmatrixProd3O) / np.mean(NmatrixProd3W)
DmatrixProd3OW = np.mean(DmatrixProd3O) / np.mean(DmatrixProd3WE)
SmatrixProd3OW = np.mean(SmatrixProd3O) / np.mean(SmatrixProd3WE)
NmatrixProd4OW = np.mean(NmatrixProd4O) / np.mean(NmatrixProd4W)
DmatrixProd4OW = np.mean(DmatrixProd4O) / np.mean(DmatrixProd4WE)
SmatrixProd4OW = np.mean(SmatrixProd4O) / np.mean(SmatrixProd4WE)

categorias = ["1", "2", "3", "4"]
valores1 = [NmatrixProd1OW, NmatrixProd2OW, NmatrixProd3OW, NmatrixProd4OW]
valores2 = [DmatrixProd1OW, DmatrixProd2OW, DmatrixProd3OW, DmatrixProd4OW]
valores3 = [SmatrixProd1OW, SmatrixProd2OW, SmatrixProd3OW, SmatrixProd4OW]
# Posición en el eje x para cada categoría
x = np.arange(len(categorias))
# Ancho de las barras
ancho = 0.3
# Crear el gráfico de barras
plt.figure(figsize=(16,9))
bar1 = plt.bar(x, valores1, ancho, label='Native', color='purple')
bar2 = plt.bar(x + ancho, valores2, ancho, label='Docker', color='red')
bar3 = plt.bar(x + 2*ancho, valores3, ancho, label='Singularity', color='blue')
# Etiquetas en el eje x
plt.xticks(x + ancho, categorias, fontsize=20)
plt.yticks( fontsize=20)
# Etiquetas de título y ejes
plt.title('MatrixProd', fontsize=40)
plt.xlabel('Cores', fontsize=30)
plt.ylabel('OPS/W', fontsize=30)
# Agregar leyenda
plt.legend(fontsize=20)
# Generar IMG
#plt.savefig('matrixProd.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico en la ventana de la aplicación
plt.show()

# %%
# Native vs Docker Deployment
DiffNDcfloat1OW = ((Ncfloat1OW - Dcfloat1OW) / Dcfloat1OW) * 100
DiffNDcfloat2OW = ((Ncfloat2OW - Dcfloat2OW) / Dcfloat2OW) * 100
DiffNDcfloat3OW = ((Ncfloat2OW - Dcfloat2OW) / Dcfloat2OW) * 100
DiffNDcfloat4OW = ((Ncfloat2OW - Dcfloat2OW) / Dcfloat2OW) * 100
DiffNDcorrelate1OW = ((Ncorrelate1OW - Dcorrelate1OW) / Dcorrelate1OW) * 100
DiffNDcorrelate2OW = ((Ncorrelate2OW - Dcorrelate2OW) / Dcorrelate2OW) * 100
DiffNDcorrelate3OW = ((Ncorrelate3OW - Dcorrelate3OW) / Dcorrelate3OW) * 100
DiffNDcorrelate4OW = ((Ncorrelate4OW - Dcorrelate4OW) / Dcorrelate4OW) * 100
DiffNDprime1OW = ((Nprime1OW - Dprime1OW) / Dprime1OW) * 100
DiffNDprime2OW = ((Nprime2OW - Dprime2OW) / Dprime2OW) * 100
DiffNDprime3OW = ((Nprime3OW - Dprime3OW) / Dprime3OW) * 100
DiffNDprime4OW = ((Nprime4OW - Dprime4OW) / Dprime4OW) * 100
DiffNDmatrixProd1OW = ((NmatrixProd1OW - DmatrixProd1OW) / DmatrixProd1OW) * 100
DiffNDmatrixProd2OW = ((NmatrixProd2OW - DmatrixProd2OW) / DmatrixProd2OW) * 100
DiffNDmatrixProd3OW = ((NmatrixProd3OW - DmatrixProd3OW) / DmatrixProd3OW) * 100
DiffNDmatrixProd4OW = ((NmatrixProd4OW - DmatrixProd4OW) / DmatrixProd4OW) * 100

# Datos para el gráfico
categorias = ["Cfloat", "Correlate", "Prime", "MatrixProd"]
valores_grupo1 = [DiffNDcfloat1OW, DiffNDcorrelate1OW, DiffNDprime1OW, DiffNDmatrixProd1OW]
valores_grupo2 = [DiffNDcfloat2OW, DiffNDcorrelate2OW, DiffNDprime2OW, DiffNDmatrixProd2OW]
valores_grupo3 = [DiffNDcfloat3OW, DiffNDcorrelate3OW, DiffNDprime3OW, DiffNDmatrixProd3OW]
valores_grupo4 = [DiffNDcfloat4OW, DiffNDcorrelate4OW, DiffNDprime4OW, DiffNDmatrixProd4OW]
ancho_barras = 0.2  # Ancho de las barras

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(9, 11))

# Definir las posiciones de las barras para cada grupo
posiciones_grupo1 = np.arange(len(valores_grupo1))
posiciones_grupo2 = [p + ancho_barras for p in posiciones_grupo1]
posiciones_grupo3 = [p + ancho_barras for p in posiciones_grupo2]
posiciones_grupo4 = [p + ancho_barras for p in posiciones_grupo3]

# Crear las barras para cada grupo
ax.barh(posiciones_grupo1, valores_grupo1, ancho_barras, label='1 Core')
ax.barh(posiciones_grupo2, valores_grupo2, ancho_barras, label='2 Cores')
ax.barh(posiciones_grupo3, valores_grupo3, ancho_barras, label='3 Cores')
ax.barh(posiciones_grupo4, valores_grupo4, ancho_barras, label='4 Cores')

# Etiquetas de título y ejes
ax.set_title('Docker Vs Native Deployment', fontsize=40)
ax.set_xlabel('% Diff OPS/W', fontsize=30)
ax.set_ylabel('TEST', fontsize=30)
ax.set_yticks(posiciones_grupo1 + 2 * ancho_barras)
ax.set_yticklabels(categorias, fontsize=20)
ax.set_xticks(np.arange(-10, 20, 5))
ax.set_xticklabels(ax.get_xticks(), fontsize=20)

# Mostrar la leyenda
ax.legend(fontsize=20)

# Generar IMG
plt.savefig('dvnd.png', dpi=300, bbox_inches='tight')

# Mostrar el gráfico
plt.show()

# %%
# Native vs Singularity Deployment
DiffNScfloat1OW = ((Ncfloat1OW - Scfloat1OW) / Scfloat1OW) * 100
DiffNScfloat2OW = ((Ncfloat2OW - Scfloat2OW) / Scfloat2OW) * 100
DiffNScfloat3OW = ((Ncfloat2OW - Scfloat2OW) / Scfloat2OW) * 100
DiffNScfloat4OW = ((Ncfloat2OW - Scfloat2OW) / Scfloat2OW) * 100
DiffNScorrelate1OW = ((Ncorrelate1OW - Scorrelate1OW) / Scorrelate1OW) * 100
DiffNScorrelate2OW = ((Ncorrelate2OW - Scorrelate2OW) / Scorrelate2OW) * 100
DiffNScorrelate3OW = ((Ncorrelate3OW - Scorrelate3OW) / Scorrelate3OW) * 100
DiffNScorrelate4OW = ((Ncorrelate4OW - Scorrelate4OW) / Scorrelate4OW) * 100
DiffNSprime1OW = ((Nprime1OW - Sprime1OW) / Sprime1OW) * 100
DiffNSprime2OW = ((Nprime2OW - Sprime2OW) / Sprime2OW) * 100
DiffNSprime3OW = ((Nprime3OW - Sprime3OW) / Sprime3OW) * 100
DiffNSprime4OW = ((Nprime4OW - Sprime4OW) / Sprime4OW) * 100
DiffNSmatrixProd1OW = ((NmatrixProd1OW - SmatrixProd1OW) / SmatrixProd1OW) * 100
DiffNSmatrixProd2OW = ((NmatrixProd2OW - SmatrixProd2OW) / SmatrixProd2OW) * 100
DiffNSmatrixProd3OW = ((NmatrixProd3OW - SmatrixProd3OW) / SmatrixProd3OW) * 100
DiffNSmatrixProd4OW = ((NmatrixProd4OW - SmatrixProd4OW) / SmatrixProd4OW) * 100

# Datos para el gráfico
categorias = ["Cfloat", "Correlate", "Prime", "MatrixProd"]
valores_grupo1 = [DiffNScfloat1OW, DiffNScorrelate1OW, DiffNSprime1OW, DiffNSmatrixProd1OW]
valores_grupo2 = [DiffNScfloat2OW, DiffNScorrelate2OW, DiffNSprime2OW, DiffNSmatrixProd2OW]
valores_grupo3 = [DiffNScfloat3OW, DiffNScorrelate3OW, DiffNSprime3OW, DiffNSmatrixProd3OW]
valores_grupo4 = [DiffNScfloat4OW, DiffNScorrelate4OW, DiffNSprime4OW, DiffNSmatrixProd4OW]
ancho_barras = 0.2  # Ancho de las barras

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(9, 11))

# Definir las posiciones de las barras para cada grupo
posiciones_grupo1 = np.arange(len(valores_grupo1))
posiciones_grupo2 = [p + ancho_barras for p in posiciones_grupo1]
posiciones_grupo3 = [p + ancho_barras for p in posiciones_grupo2]
posiciones_grupo4 = [p + ancho_barras for p in posiciones_grupo3]

# Crear las barras para cada grupo
ax.barh(posiciones_grupo1, valores_grupo1, ancho_barras, label='1 Core')
ax.barh(posiciones_grupo2, valores_grupo2, ancho_barras, label='2 Cores')
ax.barh(posiciones_grupo3, valores_grupo3, ancho_barras, label='3 Cores')
ax.barh(posiciones_grupo4, valores_grupo4, ancho_barras, label='4 Cores')

# Etiquetas de título y ejes
ax.set_title('Singularity Vs Native Deployment', fontsize=40)
ax.set_xlabel('% Diff OPS/W', fontsize=30)
ax.set_ylabel('TEST', fontsize=30)
ax.set_yticks(posiciones_grupo1 + 2 * ancho_barras)
ax.set_yticklabels(categorias, fontsize=20)
ax.set_xticks(np.arange(-10, 11, 5))
ax.set_xticklabels(ax.get_xticks(), fontsize=20)

# Mostrar la leyenda
ax.legend(fontsize=20)

# Generar IMG
plt.savefig('svnd.png', dpi=300, bbox_inches='tight')

# Mostrar el gráfico
plt.show()

# %%
# Docker vs Singularity Deployment
DiffDScfloat1OW = ((Dcfloat1OW - Scfloat1OW) / Scfloat1OW) * 100
DiffDScfloat2OW = ((Dcfloat2OW - Scfloat2OW) / Scfloat2OW) * 100
DiffDScfloat3OW = ((Dcfloat2OW - Scfloat2OW) / Scfloat2OW) * 100
DiffDScfloat4OW = ((Dcfloat2OW - Scfloat2OW) / Scfloat2OW) * 100
DiffDScorrelate1OW = ((Dcorrelate1OW - Scorrelate1OW) / Scorrelate1OW) * 100
DiffDScorrelate2OW = ((Dcorrelate2OW - Scorrelate2OW) / Scorrelate2OW) * 100
DiffDScorrelate3OW = ((Dcorrelate3OW - Scorrelate3OW) / Scorrelate3OW) * 100
DiffDScorrelate4OW = ((Dcorrelate4OW - Scorrelate4OW) / Scorrelate4OW) * 100
DiffDSprime1OW = ((Dprime1OW - Sprime1OW) / Sprime1OW) * 100
DiffDSprime2OW = ((Dprime2OW - Sprime2OW) / Sprime2OW) * 100
DiffDSprime3OW = ((Dprime3OW - Sprime3OW) / Sprime3OW) * 100
DiffDSprime4OW = ((Dprime4OW - Sprime4OW) / Sprime4OW) * 100
DiffDSmatrixProd1OW = ((DmatrixProd1OW - SmatrixProd1OW) / SmatrixProd1OW) * 100
DiffDSmatrixProd2OW = ((DmatrixProd2OW - SmatrixProd2OW) / SmatrixProd2OW) * 100
DiffDSmatrixProd3OW = ((DmatrixProd3OW - SmatrixProd3OW) / SmatrixProd3OW) * 100
DiffDSmatrixProd4OW = ((DmatrixProd4OW - SmatrixProd4OW) / SmatrixProd4OW) * 100

# Datos para el gráfico
categorias = ["Cfloat", "Correlate", "Prime", "MatrixProd"]
valores_grupo1 = [DiffDScfloat1OW, DiffDScorrelate1OW, DiffDSprime1OW, DiffDSmatrixProd1OW]
valores_grupo2 = [DiffDScfloat2OW, DiffDScorrelate2OW, DiffDSprime2OW, DiffDSmatrixProd2OW]
valores_grupo3 = [DiffDScfloat3OW, DiffDScorrelate3OW, DiffDSprime3OW, DiffDSmatrixProd3OW]
valores_grupo4 = [DiffDScfloat4OW, DiffDScorrelate4OW, DiffDSprime4OW, DiffDSmatrixProd4OW]
ancho_barras = 0.2  # Ancho de las barras

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(9, 11))

# Definir las posiciones de las barras para cada grupo
posiciones_grupo1 = np.arange(len(valores_grupo1))
posiciones_grupo2 = [p + ancho_barras for p in posiciones_grupo1]
posiciones_grupo3 = [p + ancho_barras for p in posiciones_grupo2]
posiciones_grupo4 = [p + ancho_barras for p in posiciones_grupo3]

# Crear las barras para cada grupo
ax.barh(posiciones_grupo1, valores_grupo1, ancho_barras, label='1 Core')
ax.barh(posiciones_grupo2, valores_grupo2, ancho_barras, label='2 Cores')
ax.barh(posiciones_grupo3, valores_grupo3, ancho_barras, label='3 Cores')
ax.barh(posiciones_grupo4, valores_grupo4, ancho_barras, label='4 Cores')

# Etiquetas de título y ejes
ax.set_title('Singularity Vs Docker Deployment', fontsize=40)
ax.set_xlabel('% Diff OPS/W', fontsize=30)
ax.set_ylabel('TEST', fontsize=30)
ax.set_yticks(posiciones_grupo1 + 2 * ancho_barras)
ax.set_yticklabels(categorias, fontsize=20)
ax.set_xticks(np.arange(-4, 3, 1))
ax.set_xticklabels(ax.get_xticks(), fontsize=20)

# Mostrar la leyenda
ax.legend(fontsize=20)

# Generar IMG
plt.savefig('svdd.png', dpi=300, bbox_inches='tight')

# Mostrar el gráfico
plt.show()

# %%
# Native time
N1T = [np.mean(Ncfloat1T), np.mean(Ncorrelate1T), np.mean(Nprime1T), np.mean(NmatrixProd1T)]
N2T = [np.mean(Ncfloat2T), np.mean(Ncorrelate2T), np.mean(Nprime2T), np.mean(NmatrixProd2T)]
N3T = [np.mean(Ncfloat3T), np.mean(Ncorrelate3T), np.mean(Nprime3T), np.mean(NmatrixProd3T)]
N4T = [np.mean(Ncfloat4T), np.mean(Ncorrelate4T), np.mean(Nprime4T), np.mean(NmatrixProd4T)]
D1TS = [np.mean(Dcfloat1TS), np.mean(Dcorrelate1TS), np.mean(Dprime1TS), np.mean(DmatrixProd1TS)]
D2TS = [np.mean(Dcfloat2TS), np.mean(Dcorrelate2TS), np.mean(Dprime2TS), np.mean(DmatrixProd2TS)]
D3TS = [np.mean(Dcfloat3TS), np.mean(Dcorrelate3TS), np.mean(Dprime3TS), np.mean(DmatrixProd3TS)]
D4TS = [np.mean(Dcfloat4TS), np.mean(Dcorrelate4TS), np.mean(Dprime4TS), np.mean(DmatrixProd4TS)]
D1TE = [np.mean(Dcfloat1TE), np.mean(Dcorrelate1TE), np.mean(Dprime1TE), np.mean(DmatrixProd1TE)]
D2TE = [np.mean(Dcfloat2TE), np.mean(Dcorrelate2TE), np.mean(Dprime2TE), np.mean(DmatrixProd2TE)]
D3TE = [np.mean(Dcfloat3TE), np.mean(Dcorrelate3TE), np.mean(Dprime3TE), np.mean(DmatrixProd3TE)]
D4TE = [np.mean(Dcfloat4TE), np.mean(Dcorrelate4TE), np.mean(Dprime4TE), np.mean(DmatrixProd4TE)]
D1TF = [np.mean(Dcfloat1TF), np.mean(Dcorrelate1TF), np.mean(Dprime1TF), np.mean(DmatrixProd1TF)]
D2TF = [np.mean(Dcfloat2TF), np.mean(Dcorrelate2TF), np.mean(Dprime2TF), np.mean(DmatrixProd2TF)]
D3TF = [np.mean(Dcfloat3TF), np.mean(Dcorrelate3TF), np.mean(Dprime3TF), np.mean(DmatrixProd3TF)]
D4TF = [np.mean(Dcfloat4TF), np.mean(Dcorrelate4TF), np.mean(Dprime4TF), np.mean(DmatrixProd4TF)]
S1TS = [np.mean(Scfloat1TS), np.mean(Scorrelate1TS), np.mean(Sprime1TS), np.mean(SmatrixProd1TS)]
S2TS = [np.mean(Scfloat2TS), np.mean(Scorrelate2TS), np.mean(Sprime2TS), np.mean(SmatrixProd2TS)]
S3TS = [np.mean(Scfloat3TS), np.mean(Scorrelate3TS), np.mean(Sprime3TS), np.mean(SmatrixProd3TS)]
S4TS = [np.mean(Scfloat4TS), np.mean(Scorrelate4TS), np.mean(Sprime4TS), np.mean(SmatrixProd4TS)]
S1TE = [np.mean(Scfloat1TE), np.mean(Scorrelate1TE), np.mean(Sprime1TE), np.mean(SmatrixProd1TE)]
S2TE = [np.mean(Scfloat2TE), np.mean(Scorrelate2TE), np.mean(Sprime2TE), np.mean(SmatrixProd2TE)]
S3TE = [np.mean(Scfloat3TE), np.mean(Scorrelate3TE), np.mean(Sprime3TE), np.mean(SmatrixProd3TE)]
S4TE = [np.mean(Scfloat4TE), np.mean(Scorrelate4TE), np.mean(Sprime4TE), np.mean(SmatrixProd4TE)]
S1TF = [np.mean(Scfloat1TF), np.mean(Scorrelate1TF), np.mean(Sprime1TF), np.mean(SmatrixProd1TF)]
S2TF = [np.mean(Scfloat2TF), np.mean(Scorrelate2TF), np.mean(Sprime2TF), np.mean(SmatrixProd2TF)]
S3TF = [np.mean(Scfloat3TF), np.mean(Scorrelate3TF), np.mean(Sprime3TF), np.mean(SmatrixProd3TF)]
S4TF = [np.mean(Scfloat4TF), np.mean(Scorrelate4TF), np.mean(Sprime4TF), np.mean(SmatrixProd4TF)]

categorias = ["1", "2", "3", "4"]
valores1 = [np.mean(N1T), np.mean(N2T), np.mean(N3T), np.mean(N4T)]
valores2 = [np.mean(D1TS), np.mean(D2TS), np.mean(D3TS), np.mean(D4TS)]
valores3 = [np.mean(S1TS), np.mean(S2TS), np.mean(S3TS), np.mean(S4TS)]
valores4 = [np.mean(D1TE), np.mean(D2TE), np.mean(D3TE), np.mean(D4TE)]
valores5 = [np.mean(S1TE), np.mean(S2TE), np.mean(S3TE), np.mean(S4TE)]
valores6 = [np.mean(D1TF), np.mean(D2TF), np.mean(D3TF), np.mean(D4TF)]
valores7 = [np.mean(S1TF), np.mean(S2TF), np.mean(S3TF), np.mean(S4TF)]
# Posición en el eje x para cada categoría
x = np.arange(len(categorias))
# Ancho de las barras
ancho = 0.3
# Crear el gráfico de barras
plt.figure(figsize=(16,9))
bar1 = plt.bar(x, valores1, ancho, label='Start/Execute Native', color='purple')
bar2 = plt.bar(x + ancho, valores2, ancho, label='Start Docker', color='red')
bar3 = plt.bar(x + 2*ancho, valores3, ancho, label='Start Singularity', color='blue')
bar4 = plt.bar(x + ancho, valores4, ancho, label='Execute Docker', color='green', bottom=valores2)
bar5 = plt.bar(x + 2*ancho, valores5, ancho, label='Execute Singularity', color='#00FF00', bottom=valores3)
bar6 = plt.bar(x + ancho, valores6, ancho, label='Stop Docker', color='grey', bottom=np.array(valores2) + np.array(valores4))
bar7 = plt.bar(x + 2*ancho, valores7, ancho, label='Stop Singularity', color='#009955', bottom=np.array(valores3) + np.array(valores5))
# Etiquetas en el eje x
plt.xticks(x + ancho, categorias, fontsize=20)
plt.yticks( fontsize=20)
# Etiquetas de título y ejes
plt.title('Execution Total Time ', fontsize=40)
plt.xlabel('Cores', fontsize=30)
plt.ylabel('Second', fontsize=30)
# Agregar leyenda
plt.legend(loc='upper right', bbox_to_anchor=(1, 0.5), fontsize=16)
# Generar IMG
plt.savefig('ett.png', dpi=300, bbox_inches='tight')
# Mostrar el gráfico en la ventana de la aplicación
plt.show()

# %%
import networkx as nx

# Crear un grafo dirigido
G = nx.DiGraph()

# Agregar nodos
G.add_node("1")
G.add_node("2")
G.add_node("3")
G.add_node("4")
G.add_node("5")
G.add_node("6")

# Agregar arcos
G.add_edge("1", "2")
G.add_edge("2", "3")
G.add_edge("3", "4")
G.add_edge("4", "5")
G.add_edge("5", "6")
G.add_edge("5", "1")

# Dibujar el grafo
radius = 1  # Radio del diseño circular
offset = 0.15  # Desplazamiento para colocar el primer nodo en la posición izquierda superior
pos["1"] = (radius * offset, radius * (1 - offset))
pos = nx.circular_layout(G)  # Posiciones de los nodos
nx.draw(G, pos, with_labels=True, node_size=2000, node_color='skyblue', font_size=16, font_color='black', font_weight='bold')

# Mostrar el diagrama de flujo
#plt.title('Diagrama de Flujo')
#plt.axis('off')  # Ocultar ejes
plt.show()
